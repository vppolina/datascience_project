# %% [markdown]
# # Dataset Exploration
#
# First, we will show you how to explore the dataset, how to pre-process it and how to start making initial visualizations.

# %% [markdown]
# ## Library Imports

# %%
# Import Os to get to the root directory
import os
import sys

# Root directory of the project
ROOT_DIR = os.path.abspath("../")
sys.path.append(ROOT_DIR)

# Import own functions
from libraries import corpus
from libraries import pdf2text

# Import other libraries
import nltk 
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
from importlib import reload
reload(corpus)
# Out:
# <module 'libraries.corpus' from 'D:\\Dropbox\\Masters\\BIPM\\2 Semester\\Text, Web and Social Media Analytics\\Project\\datascience_project\\libraries\\corpus.py'>

# %% [markdown]
# ## Data Preprocessing

# %%
# Get the Dataset from the White-Paper folders, converting all PDFs into text
dataset = pdf2text.get_dataset()
# Out:
# 2019-06-04 22:38:48,725 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...

# %%
# Name of all the White Papers in our dataset
dataset.keys()
# Out:
# dict_keys(['0chain', '1World', '1x2Coin', 'AB-CHAIN', 'ABCC', 'ABLE', 'Absolute', 'ACE', 'Achain', 'AcreCoin', 'Actinium', 'AcuteAngle', 'Adamant', 'AdBank', 'AdChainRegistry', 'AdCoin', 'Adhive', 'Aditus', 'Adshares', 'Alluva', 'Ample!', 'ArkIO', 'BasicAttentionToken', 'Binance', 'Bitcoin', 'BitcoinGold', 'BitStash', 'Budbo', 'Bytecoin', 'CONUN', 'Cosmos', 'CryptoNote', 'DaiStableCoinSystem', 'Dash', 'Decentraland', 'Digix', 'Enjin', 'EtherAce', 'Ethereum', 'EthereumClassic', 'Giant', 'GiveCoin', 'Golem', 'GuaranteedEntranceToken', 'GXChain', 'HuobiPoolToken', 'ICON', 'IOTA', 'KwattCoin', 'Latoken', 'MoneroV', 'Neox', 'Oxcert', 'RippleProtocol', 'Safe', 'SDUSD', 'SnipCoin', 'Solve', 'Steem', 'StellarConcensusProtocol', 'Tether', 'Tezos', 'Tron', 'Vechain', 'Zerocash'])

# %%
# Number of White Papers in our dataset
len(dataset.keys())
# Out:
# 65

# %%
# Example on how to examine a unprocessed White Paper
dataset["0chain"]
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n0chain Whitepaper V2.0 (PDF)\n\n\n 1\n\n0C̷hain: A Fast, Secure, Scalable, \n& Free Blockchain\nTailored For High-Performance, Zero-Trust, Decentralized Storage\n\nWhitepaper V2.0 Last Updated Mar. 20, 2019 Subject To Further Review & Update\n\nSaswata Basu, Thomas Austin, Siva Dirisala, & 0̷Chain Team\n\n\n\n 2\n\nTable Of Contents \n\nIntroduction\n\nMOTIVATION\n\nEXECUTIVE SUMMARY\n\n1. AN INTRODUCTION TO 0̷CHAIN\n\n2. PRODUCTS\n\n2.1 0̷CHAINNET \n\n2.2 0̷BOX \n\n2.3 0̷WALLET \n\n3. 0̷CHAIN ARCHITECTURE\n\n3.1 CONSENSUS PROTOCOL\n\n    3.2 STORAGE PROTOCOL \n\n    3.3 SPLIT KEY PROTOCOL \n\n    3.4 TOKEN REWARD PROTOCOL \n\n    3.5 GOVERNANCE PROTOCOL \n\n    3.6 OTHER PROTOCOLS \n\n4. APPENDICES\n\nAPPENDIX 1: TEAM\nAPPENDIX 2: UNDERSTANDING 0̷CHAIN FINALITY \n\nAPPENDIX 3: CONSENSUS PROTOCOL  \nAPPENDIX 4: STORAGE & TOKEN REWARD PROTOCOL \nAPPENDIX 5: SPLIT KEY PROTOCOL\n\n3\n4\n9\n13\n\n23\n24\n25\n26\n26\n27\n27\n\n29\n30\n36\n38\n40\n\n14\n18\n22\n\n\n\n 3\n\nMotivation \nWhen we started developing 0̷Chain in July 2017, we were driven by the idea of redefining the cloud \n\nin the context of privacy, transparency, and user control of data. In 2018, as we dove deeper into our \n\ndevelopment process, we identified a number of critical unresolved issues in the cryptocurrency \n\nspace, such as: token security, token valuation metrics, governance, and token inflation. To address \n\nthe aforementioned issues, we chose to conduct additional research and development. Today, we \n\nare not just redefining the cloud, but the blockchain and cryptocurrency landscape through our novel \n\nprotocols. \n\nWhitepaper\n\n\n\n 4\n\nExecutive Summary \n\nExecutive Summary\n\nSeveral roadblocks exist in today’s crypto market, as well as the underlying Distributed Ledger Technologies \n(DLT) that power them — hindering the maturation process of the blockchain industry. Some are regulatory \nand security concerns, some involve technical performance, while other issues are related to token \neconomics, valuation metrics, and governance.  \n\n1. SECURITY\n\nRegulators identify a few key shortcomings with regards to the security of crypto assets: poor wallet infrastructure, exchange \n\ntransparency, and unreliable custody of assets. 0̷Chain is addressing all of these issues. \n\nToday, hardware wallets are clunky and extremely hard to use for an average person, especially for daily utility. Software wallets \n\nare notoriously prone to hacking, unless you can memorize your private key. Our software-based secure wallet is the world’s first \n\nto enable a 2-device authentication; it makes transactions simple and yet highly secure with just a mobile device and a laptop.\n\n2. SPEED AND SCALABILITY\n\nThe finality for Bitcoin is about 1 hour; Ethereum is about 3-10 minutes — something that is still too slow for a micropayment \n\ntransaction and verification. We aim to address this problem. 0̷ChainNet is a high speed blockchain with block finality achieved \n\nwithin . 5 to 1.5 seconds (depending on network latency), highly scalable with throughput rates of over 1,000 transactions per \n\nsecond, and energy efficient by way of our unique Proof of Stake protocol. We have proven these results on a public test \n\nnetwork of 10 worldwide data centers and have completed over 6 billion transactions to verify reliability. \n\n3. ARCHITECTURE\n\nAn Ethereum node mines a block, stores the block, and stores associated unstructured data, all on the same node. This same \n\nnode handles transactions and queries from the same client. This architecture makes the node very expensive, slow and unscalable. \n\n0̷Chain architecture allows for separation of duties to specific designated nodes, called miners, sharders, and blobbers. Miners \n\nreceive transactions from users and they generate blocks via the consensus protocol, Sharders store these blocks and respond \n\nto queries on tra ...

# %%
# Define if you want your corpus to be whole or divided in sentences
makeSentences = False
# Creates a dictionary with each White Paper and its text pre-processed
corpora = corpus.makeCleanCorpus(dataset, lemmatize=False, removePunct=True, removeNums=True
                                 ,makeSentences=makeSentences, removeURL=True, removeChar=True)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\luisd\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\luisd\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\luisd\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\luisd\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Cleaning: 0chain
# Cleaning: 1World
# Cleaning: 1x2Coin
# Cleaning: AB-CHAIN
# Cleaning: ABCC
# Cleaning: ABLE
# Cleaning: Absolute
# Cleaning: ACE
# Cleaning: Achain
# Cleaning: AcreCoin
# Cleaning: Actinium
# Cleaning: AcuteAngle
# Cleaning: Adamant
# Cleaning: AdBank
# Cleaning: AdChainRegistry
# Cleaning: AdCoin
# Cleaning: Adhive
# Cleaning: Aditus
# Cleaning: Adshares
# Cleaning: Alluva
# Cleaning: Ample!
# Cleaning: ArkIO
# Cleaning: BasicAttentionToken
# Cleaning: Binance
# Cleaning: Bitcoin
# Cleaning: BitcoinGold
# Cleaning: BitStash
# Cleaning: Budbo
# Cleaning: Bytecoin
# Cleaning: CONUN
# Cleaning: Cosmos
# Cleaning: CryptoNote
# Cleaning: DaiStableCoinSystem
# Cleaning: Dash
# Cleaning: Decentraland
# Cleaning: Digix
# Cleaning: Enjin
# Cleaning: EtherAce
# Cleaning: Ethereum
# Cleaning: EthereumClassic
# Cleaning: Giant
# Cleaning: GiveCoin
# Cleaning: Golem
# Cleaning: GuaranteedEntranceToken
# Cleaning: GXChain
# Cleaning: HuobiPoolToken
# Cleaning: ICON
# Cleaning: IOTA
# Cleaning: KwattCoin
# Cleaning: Latoken
# Cleaning: MoneroV
# Cleaning: Neox
# Cleaning: Oxcert
# Cleaning: RippleProtocol
# Cleaning: Safe
# Cleaning: SDUSD
# Cleaning: SnipCoin
# Cleaning: Solve
# Cleaning: Steem
# Cleaning: StellarConcensusProtocol
# Cleaning: Tether
# Cleaning: Tezos
# Cleaning: Tron
# Cleaning: Vechain
# Cleaning: Zerocash
# Done!

# %%
# All the White Papers pre-processed
corpora.keys()
# Out:
# dict_keys(['0chain'])

# %%
# Explore an specific corpus of a White Paper
corpora["0chain"]
# Out:
# 'chain whitepaper pdf chain fast secure scalable free blockchain tailored highperformance zerotrust decentralized storage whitepaper last updated mar subject review update saswata basu thomas austin siva dirisala chain team table contents introduction motivation executive summary introduction chain products chainnet box wallet chain architecture consensus protocol storage protocol split key protocol token reward protocol governance protocol protocols appendices appendix team appendix understanding chain finality appendix consensus protocol appendix storage token reward protocol appendix split key protocol motivation started developing chain july driven idea redefining cloud context privacy transparency user control data dove deeper development process identified number critical unresolved issues cryptocurrency space token security token valuation metrics governance token inflation address aforementioned issues chose conduct additional research development today redefining cloud blockchain cryptocurrency landscape novel protocols whitepaper executive summary executive summary several roadblocks exist today crypto market well underlying distributed ledger technologies dlt power hindering maturation process blockchain industry regulatory security concerns involve technical performance issues related token economics valuation metrics governance security regulators identify key shortcomings regards security crypto assets poor wallet infrastructure exchange transparency unreliable custody assets chain addressing issues today hardware wallets clunky extremely hard use average person especially daily utility software wallets notoriously prone hacking unless memorize private key softwarebased secure wallet world first enable device authentication makes transactions simple yet highly secure mobile device laptop speed scalability finality bitcoin hour ethereum minutes something still slow micropayment transaction verification aim address problem chainnet high speed blockchain block finality achieved within seconds depending network latency highly scalable throughput rates transactions per second energy efficient way unique proof stake protocol proven results public test network worldwide data centers completed billion transactions verify reliability architecture ethereum node mines block stores block stores associated unstructured data node node handles transactions queries client architecture makes node expensive slow unscalable chain architecture allows separation duties specific designated nodes called miners sharders blobbers miners receive transactions users generate blocks via consensus protocol sharders store blocks respond queries transactions blocks blobbers store unstructured data architecture allows offtheshelf cheap hardware making inexpensive support network node faster response rates better scalability executive summary zcn token value zcn mathematically related data stored services network unlike cryptocurrency addressing cost value volatility expensive transaction fees volatility native blockchain cryptocurrencies unresolved problem today public blockchain networks address pain point chain native cryptocurrency zcn uniquely programmed assetbacked token user locks zcn tokens collect interest used toward payment transactions data services interestbearing feature transaction fee absorbed interest generated locked tokens additionally chainnet core service data storage also enabled locked tokens upon locking storage service activated extent service determined number tokens locked user details refer section services initial locked tokens fully redeemable upon unlocking thus facilitating free services network free network mints tokens part inflation underlying token economics storage transaction services quantifiable real world market value conversely frequently argued popular native blockchain cryptocurrencies btc eth etc current state lack economic value beyond raw speculation creates challenging process accurate price discove ...

# %%
# Function that converts a dictionary into a Pandas Dataframe
# The indexes are the name of the files
df = corpus.dictionaryToPandas(corpora)

# %%
# Define to show all the data
pd.set_option('display.max_colwidth', 100)
# Inspect the DataFrame
df.head()
# Out:
#                                                                                                          text
# 0chain    chain whitepaper pdf chain fast secure scalable free blockchain tailored highperformance zerotru...
# 1World    legal disclaimer purpose white paper present world online wo token potential token holders conne...
# 1x2Coin   powerpoint presentation whitepaper table contents introduction masternodes coinholders proofofst...
# AB-CHAIN  abchain blockchain effect ive advert ing drive traffic ico companies cryptocurrency budgets tabl...
# ABCC      abcc digital asset exchange vpages index vision background opportunities pain points addressed l...

# %%
# Explore a White Paper text within a DataFrame (corpus or sentences)
df.loc["0chain"][0]
# Out:
# 'chain whitepaper pdf chain fast secure scalable free blockchain tailored highperformance zerotrust decentralized storage whitepaper last updated mar subject review update saswata basu thomas austin siva dirisala chain team table contents introduction motivation executive summary introduction chain products chainnet box wallet chain architecture consensus protocol storage protocol split key protocol token reward protocol governance protocol protocols appendices appendix team appendix understanding chain finality appendix consensus protocol appendix storage token reward protocol appendix split key protocol motivation started developing chain july driven idea redefining cloud context privacy transparency user control data dove deeper development process identified number critical unresolved issues cryptocurrency space token security token valuation metrics governance token inflation address aforementioned issues chose conduct additional research development today redefining cloud blockchain cryptocurrency landscape novel protocols whitepaper executive summary executive summary several roadblocks exist today crypto market well underlying distributed ledger technologies dlt power hindering maturation process blockchain industry regulatory security concerns involve technical performance issues related token economics valuation metrics governance security regulators identify key shortcomings regards security crypto assets poor wallet infrastructure exchange transparency unreliable custody assets chain addressing issues today hardware wallets clunky extremely hard use average person especially daily utility software wallets notoriously prone hacking unless memorize private key softwarebased secure wallet world first enable device authentication makes transactions simple yet highly secure mobile device laptop speed scalability finality bitcoin hour ethereum minutes something still slow micropayment transaction verification aim address problem chainnet high speed blockchain block finality achieved within seconds depending network latency highly scalable throughput rates transactions per second energy efficient way unique proof stake protocol proven results public test network worldwide data centers completed billion transactions verify reliability architecture ethereum node mines block stores block stores associated unstructured data node node handles transactions queries client architecture makes node expensive slow unscalable chain architecture allows separation duties specific designated nodes called miners sharders blobbers miners receive transactions users generate blocks via consensus protocol sharders store blocks respond queries transactions blocks blobbers store unstructured data architecture allows offtheshelf cheap hardware making inexpensive support network node faster response rates better scalability executive summary zcn token value zcn mathematically related data stored services network unlike cryptocurrency addressing cost value volatility expensive transaction fees volatility native blockchain cryptocurrencies unresolved problem today public blockchain networks address pain point chain native cryptocurrency zcn uniquely programmed assetbacked token user locks zcn tokens collect interest used toward payment transactions data services interestbearing feature transaction fee absorbed interest generated locked tokens additionally chainnet core service data storage also enabled locked tokens upon locking storage service activated extent service determined number tokens locked user details refer section services initial locked tokens fully redeemable upon unlocking thus facilitating free services network free network mints tokens part inflation underlying token economics storage transaction services quantifiable real world market value conversely frequently argued popular native blockchain cryptocurrencies btc eth etc current state lack economic value beyond raw speculation creates challenging process accurate price discove ...

# %% [markdown]
# ## Data Exploration

# %%
# Start tokenizing your dataset
tokenizer = nltk.tokenize.RegexpTokenizer('\s+', gaps=True)

if makeSentences:
    #############################################
    # Tokenization on sentences
    tokens = [tokenizer.tokenize(s) for s in corpora["0chain"]]
    # Flatten the list
    tokens = np.reshape(np.concatenate(tokens), -1)
    #############################################
else:
    #############################################
    # Tokenization on whole corpus (no sentences)
    tokens = tokenizer.tokenize(corpora["0chain"])
    #############################################



print('We have', len(tokens), 'words in total. \n')
print(tokens[5:10])
# Out:
# We have 3949 words in total.
#
# ['secure', 'scalable', 'free', 'blockchain', 'tailored']

# %%
from nltk.probability import FreqDist

# Turn corpus into np before unnest the list
 # numpy can handle text as well

fdist = FreqDist(tokens)

fdist.most_common(5)

import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
from nltk import bigrams, ngrams
bigrams_tokens = bigrams(tokens)
fdist_bigrams = FreqDist(list(bigrams_tokens))
fdist_bigrams.plot(30,cumulative=False)
plt.show()
