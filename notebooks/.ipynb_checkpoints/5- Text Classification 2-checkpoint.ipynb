# %% [markdown]
# # Text Classification

# %% [markdown]
# ## Library Imports

# %%
# Import Os to get to the root directory
import os
import sys

# Root directory of the project
ROOT_DIR = os.path.abspath("../")
sys.path.append(ROOT_DIR)

# Import own functions
from libraries import corpus
from libraries import pdf2text

# Import other libraries
import nltk 
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
from importlib import reload
reload(corpus)
# Out:
# <module 'libraries.corpus' from 'D:\\Dropbox\\Masters\\BIPM\\2 Semester\\Text, Web and Social Media Analytics\\Project\\datascience_project\\libraries\\corpus.py'>

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = pdf2text.get_dataset()

# %%
dataset.keys()
# Out:
# dict_keys(['0chain', '1World', '1x2Coin', 'AB-CHAIN', 'ABCC', 'ABLE', 'Absolute', 'ACE', 'Achain', 'AcreCoin', 'Actinium', 'AcuteAngle', 'Adamant', 'AdBank', 'AdChainRegistry', 'AdCoin', 'Adhive', 'Aditus', 'Adshares', 'Ample!', 'BasicAttentionToken', 'Binance', 'Bitcoin', 'BitcoinGold', 'Cosmos', 'CryptoNote', 'DaiStableCoinSystem', 'Dash', 'EtherAce', 'Ethereum', 'EthereumClassic', 'Giant', 'GiveCoin', 'GuaranteedEntranceToken', 'IOTA', 'KwattCoin', 'Oxcert', 'RippleProtocol', 'StellarConcensusProtocol', 'Tether', 'Tezos', 'Tron', 'Vechain', 'Zerocash'])

# %%
len(dataset.keys())
# Out:
# 44

# %%
dataset['Ethereum']
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nethereum\n\n\n1. A Next-Generation Smart Contract and Decentralized \nApplication Platform\n\n[![Documentation](https://img.shields.io/badge/gitter-\nDocs%20chat-4AB495.svg)](https://gitter.im/ethereum/\ndocumentation)\n> An introductory paper to Ethereum, introduced before launch, \nwhich is maintained.\n\nSatoshi Nakamoto\'s development of Bitcoin in 2009 has often been \nhailed as a radical development in money and currency, being the \nfirst example of a digital asset which simultaneously has no backing \nor [intrinsic](http://bitcoinmagazine.com/8640/an-exploration-of-\nintrinsic-value-what-it-is-why-bitcoin-doesnt-have-it-and-why-\nbitcoin-does-have-it/) and no centralized issuer or controller. \nHowever, another - arguably more important - part of the Bitcoin \nexperiment is the underlying blockchain technology as a tool of \ndistributed consensus, and attention is rapidly starting to shift to this \nother aspect of Bitcoin. Commonly cited alternative applications of \nblockchain technology include using on-blockchain digital assets to \nrepresent custom currencies and financial instruments ([colored]\n(https://docs.google.com/a/buterin.com/document/d/\n1AnkP_cVZTCMLIzw4DvsW6M8Q2JC0lIzrTLuoWu2z1BE/edit)), \nthe ownership of an underlying physical device ([smart](https://\nen.bitcoin.it/wiki/Smart_Property)), non-fungible assets such as \ndomain names ([Namecoin](http://namecoin.org)), as well as more \ncomplex applications involving having digital assets being directly \ncontrolled by a piece of code implementing arbitrary rules ([smart]\n(http://www.fon.hum.uva.nl/rob/Courses/InformationInSpeech/\nCDROM/Literature/LOTwinterschool2006/szabo.best.vwh.net/\nidea.html)) or even blockchain-based [decentralized](http://\nbitcoinmagazine.com/7050/bootstrapping-a-decentralized-\nautonomous-corporation-part-i/) (DAOs). What Ethereum intends to \nprovide is a blockchain with a built-in fully fledged Turing-complete \nprogramming language that can be used to create "contracts" that \ncan be used to encode arbitrary state transition functions, allowing \nusers to create any of the systems described above, as well as \nmany others that we have not yet imagined, simply by writing up the \nlogic in a few lines of code.\n\nhttps://img.shields.io/badge/gitter-Docs%20chat-4AB495.svg)%5D(https://gitter.im/ethereum/documentation\nhttps://img.shields.io/badge/gitter-Docs%20chat-4AB495.svg)%5D(https://gitter.im/ethereum/documentation\nhttps://img.shields.io/badge/gitter-Docs%20chat-4AB495.svg)%5D(https://gitter.im/ethereum/documentation\nhttp://bitcoinmagazine.com/8640/an-exploration-of-intrinsic-value-what-it-is-why-bitcoin-doesnt-have-it-and-why-bitcoin-does-have-it/\nhttp://bitcoinmagazine.com/8640/an-exploration-of-intrinsic-value-what-it-is-why-bitcoin-doesnt-have-it-and-why-bitcoin-does-have-it/\nhttp://bitcoinmagazine.com/8640/an-exploration-of-intrinsic-value-what-it-is-why-bitcoin-doesnt-have-it-and-why-bitcoin-does-have-it/\nhttp://bitcoinmagazine.com/8640/an-exploration-of-intrinsic-value-what-it-is-why-bitcoin-doesnt-have-it-and-why-bitcoin-does-have-it/\nhttps://docs.google.com/a/buterin.com/document/d/1AnkP_cVZTCMLIzw4DvsW6M8Q2JC0lIzrTLuoWu2z1BE/edit\nhttps://docs.google.com/a/buterin.com/document/d/1AnkP_cVZTCMLIzw4DvsW6M8Q2JC0lIzrTLuoWu2z1BE/edit\nhttps://en.bitcoin.it/wiki/Smart_Property\nhttps://en.bitcoin.it/wiki/Smart_Property\nhttp://namecoin.org/\nhttp://www.fon.hum.uva.nl/rob/Courses/InformationInSpeech/CDROM/Literature/LOTwinterschool2006/szabo.best.vwh.net/idea.html\nhttp://www.fon.hum.uva.nl/rob/Courses/InformationInSpeech/CDROM/Literature/LOTwinterschool2006/szabo.best.vwh.net/idea.html\nhttp://www.fon.hum.uva.nl/rob/Courses/InformationInSpeech/CDROM/Literature/LOTwinterschool2006/szabo.best.vwh.net/idea.html\nhttp://bitcoinmagazine.com/7050/bootstrapping-a-decentralized-autonomous-corporation-part-i/\nhttp://bitcoinmagazine.com/7050/bootstra ...

# %%
corpora = corpus.makeCleanCorpus(dataset, lemmatize=True, removePunct=True, removeNums=True,makeSentences=True, removeURL=True)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\luisd\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Cleaning: 0chain
# Cleaning: 1World
# Cleaning: 1x2Coin
# Cleaning: AB-CHAIN
# Cleaning: ABCC
# Cleaning: ABLE
# Cleaning: Absolute
# Cleaning: ACE
# Cleaning: Achain
# Cleaning: AcreCoin
# Cleaning: Actinium
# Cleaning: AcuteAngle
# Cleaning: Adamant
# Cleaning: AdBank
# Cleaning: AdChainRegistry
# Cleaning: AdCoin
# Cleaning: Adhive
# Cleaning: Aditus
# Cleaning: Adshares
# Cleaning: Ample!
# Cleaning: BasicAttentionToken
# Cleaning: Binance
# Cleaning: Bitcoin
# Cleaning: BitcoinGold
# Cleaning: Cosmos
# Cleaning: CryptoNote
# Cleaning: DaiStableCoinSystem
# Cleaning: Dash
# Cleaning: EtherAce
# Cleaning: Ethereum
# Cleaning: EthereumClassic
# Cleaning: Giant
# Cleaning: GiveCoin
# Cleaning: GuaranteedEntranceToken
# Cleaning: IOTA
# Cleaning: KwattCoin
# Cleaning: Oxcert
# Cleaning: RippleProtocol
# Cleaning: StellarConcensusProtocol
# Cleaning: Tether
# Cleaning: Tezos
# Cleaning: Tron
# Cleaning: Vechain
# Cleaning: Zerocash
# Done!

# %%
corpora.keys()
# Out:
# dict_keys(['0chain', '1World', '1x2Coin', 'AB-CHAIN', 'ABCC', 'ABLE', 'Absolute', 'ACE', 'Achain', 'AcreCoin', 'Actinium', 'AcuteAngle', 'Adamant', 'AdBank', 'AdChainRegistry', 'AdCoin', 'Adhive', 'Aditus', 'Adshares', 'Ample!', 'BasicAttentionToken', 'Binance', 'Bitcoin', 'BitcoinGold', 'Cosmos', 'CryptoNote', 'DaiStableCoinSystem', 'Dash', 'EtherAce', 'Ethereum', 'EthereumClassic', 'Giant', 'GiveCoin', 'GuaranteedEntranceToken', 'IOTA', 'KwattCoin', 'Oxcert', 'RippleProtocol', 'StellarConcensusProtocol', 'Tether', 'Tezos', 'Tron', 'Vechain', 'Zerocash'])

# %%
corpora["Ethereum"]
# Out:
# ['ethereum ',
#  'nextgeneration smart contract decentralize application platform documentation introductory paper ethereum introduce launch maintain ',
#  'satoshi nakamotos development bitcoin often hail radical development money currency example digital asset simultaneously backing intrinsic centralize issuer controller ',
#  'however arguably important part bitcoin experiment underlie blockchain technology tool distribute consensus attention rapidly start shift aspect bitcoin ',
#  'commonly cite alternative application blockchain technology include use onblockchain digital asset represent custom currency financial instrument color ownership underlie physical device smarthttps enbitcoinitwikismartproperty nonfungible asset domain name namecoin complex application involve digital asset directly control piece code implement arbitrary rule smart blockchainbased decentralizedhttp bitcoinmagazinecombootstrappingadecentralized autonomouscorporationparti daos ',
#  'ethereum intend provide blockchain builtin fully fledge turingcomplete program language use create contract use encode arbitrary state transition function allow user create system described others yet imagine simply write logic line code ',
#  'ddd◦ content introductionintroductiontobitcoinandexistingconcepts historyhistory bitcoin state transition systembitcoinasa statetransitionsystem miningmining merkle treesmerkletrees alternative blockchain applicationsalternative blockchainapplications scriptingscripting ethereumethereum philosophyphilosophy ethereum accountsethereumaccounts message transactionsmessagesand transaction messagesmessages ethereum state transition functionethereumstate transitionfunction code executioncodeexecution blockchain miningblockchainandmining applicationsapplications token systemstokensystems financial derivative stablevalue currency financialderivativesandstablevaluecurrencies identity reputation systemsidentityand reputationsystems decentralize file storagedecentralizedfile storage decentralize autonomous organization decentralizedautonomousorganizations far applicationsfurtherapplications miscellaneamiscellaneaandconcerns modify ghost implementationmodifiedghost implementation feesfees computation turingcompletenesscomputation andturingcompleteness currency issuancecurrencyandissuance mining centralizationminingcentralization scalabilityscalability conclusionconclusion notesnotesandfurtherreading notesnotes far readingfurtherreading ',
#  'introduction bitcoin exist concept history concept decentralize digital currency alternative application like property registry around decade ',
#  'anonymous ecash protocol mostly reliant cryptographic primitive chaumian blinding provide currency high degree privacy protocol largely fail gain traction reliance centralize intermediary ',
#  'wei dais bmoneyhttp wwwweidaicombmoneytxt become proposal introduce idea create money solve computational puzzle decentralize consensus proposal scant detail decentralize consensus actually implement ',
#  'hal finney introduce concept reusable system us idea bmoney together adam computationally difficult hashcash puzzle create concept cryptocurrency fell short ideal rely trust compute backend ',
#  'decentralize currency implement practice satoshi nakamoto combine establish primitive manage ownership public key cryptography consensus algorithm keep track coin proof work ',
#  'mechanism behind proof work breakthrough space simultaneously solve problem ',
#  'provide simple moderately effective consensus algorithm allow node network collectively agree set canonical update state bitcoin ledger ',
#  'second provide mechanism allow free entry consensus solve political problem decide influence consensus simultaneously prevent sybil attack ',
#  'substitute formal barrier participation requirement register unique entity particular list economic barrier weight single node consensus voting process directly proportional compute power node brings ',
#  'since alternative approach propose proof stake calculate weight node proportional currency holding computational resource discussion relative merit approach beyond scope paper note approach use serve backbone cryptocurrency ',
#  'blog post vitalik buterin founder ethereum ethereum ',
#  'blog post history ',
#  'bitcoin state transition system statetransitionpng technical standpoint ledger cryptocurrency bitcoin thought state transition system state consist ownership status exist bitcoins state transition function state transaction output new state result ',
#  'standard banking system example state balance sheet transaction request move x b state transition function reduces value account x increase value b account x account less x state transition function return error ',
#  'hence formally define applystx error banking system define alice bob send alice bob alice bob apply alice bob send alice bob error state bitcoin collection coin technically unspent transaction output utxo mine yet spent utxo denomination owner define byte address essentially cryptographic public keyfn transaction contains input input contain reference exist utxo cryptographic signature produce private key associate owner address output output contain new utxo add state ',
#  'state transition function applystx define roughly follow ',
#  'input tx reference utxo return error ',
#  'provide signature match owner utxo return error ',
#  'sum denomination input utxo less sum denomination output utxo return error ',
#  'return input utxo remove output utxo add ',
#  'half step prevents transaction sender spending coin exist second half step prevents transaction sender spending people coin second step enforces conservation value ',
#  'order use payment protocol follow ',
#  'suppose alice want send ',
#  'btc bob ',
#  'alice set available utxo total least ',
#  'btc ',
#  'realistically alice able exactly ',
#  'btc address owner second output remain ',
#  'btc change owner alice ',
#  'mining blockpicturejpg access trustworthy centralize service system trivial implement simply cod exactly described use centralize server hard drive keep track state ',
#  'however bitcoin try build decentralize currency system need combine state transition system consensus system order ensure everyone agrees order transaction ',
#  'bitcoins decentralize consensus process require node network continuously attempt produce package transaction block ',
#  'network intend produce roughly block ten minute block contain timestamp nonce reference ie ',
#  'hash previous block list transaction since previous block ',
#  'creates persistent evergrowing blockchain constantly update represent late state bitcoin ledger ',
#  'algorithm check block valid express paradigm follow ',
#  'check previous block reference block exists valid ',
#  'check timestamp block previous blockfn ',
#  'less hour future ',
#  'check proof work block valid ',
#  'state end previous block ',
#  'suppose tx block transaction list n transaction ',
#  ' n set si applysitxi application return error exit return false ',
#  'return true register sn state end block ',
#  'transaction block provide valid state transition canonical state transaction execute new state ',
#  'note state encode block purely abstraction remember validate node securely compute block start genesis state sequentially apply transaction block ',
#  'additionally note order miner include transaction block matter transaction b block b spends utxo create block valid b otherwise ',
#  'validity condition present list found system requirement proof work ',
#  'precise condition doublesha hash block treat bit number less dynamically adjust target write approximately ',
#  'purpose block creation computationally hard thereby prevent sybil attacker remake entire blockchain favor ',
#  'sha design completely unpredictable pseudorandom function create valid block simply trial error repeatedly incrementing nonce new hash match ',
#  'current target network average try valid block found general target recalibrated network block average new block produce node network ten minute ',
#  'order compensate miner computational work miner block entitle include transaction ',
#  'btc nowhere ',
#  'additionally transaction high total denomination input output difference also miner transaction fee ',
#  'incidentally also mechanism btc issue genesis state contain coin ',
#  'order understand purpose mining u examine happens event malicious attacker ',
#  'since bitcoins underlie cryptography secure attacker target part bitcoin system protect cryptography directly order transaction ',
#  'attacker strategy simple ',
#  'send btc merchant exchange product preferably rapiddelivery digital ',
#  'wait delivery product ',
#  'produce transaction send btc ',
#  'try convince network transaction ',
#  'step minute miner include transaction block block number ',
#  'hour five block add chain block block indirectly point transaction thus confirm ',
#  'point merchant accept payment finalize deliver product since assume digital delivery instant ',
#  'attacker creates transaction send btc ',
#  'attacker simply release wild transaction process miner attempt run applystx notice tx consumes utxo longer state ',
#  'instead attacker creates fork blockchain start mining version block point block parent new transaction ',
#  'block data different require redo proof work ',
#  'furthermore attacker new version block different hash original block point thus original chain attacker new chain completely separate ',
#  'rule fork blockchain truth legitimate miner work chain attacker alone work chain ',
#  'order attacker blockchain need computational power rest network combine order catch hence attack ',
#  'merkle tree spv left suffices present small number node merkle tree proof validity branch ',
#  'attempt change part merkle tree eventually lead inconsistency somewhere chain ',
#  'important scalability feature bitcoin block store multilevel data structure ',
#  'hash block actually hash block header roughly byte piece data contains timestamp nonce previous block hash root hash data structure merkle tree store transaction block ',
#  'merkle tree type binary tree compose set node large number leaf node bottom tree contain underlie data set intermediate node node hash child finally single root node also form hash child represent top tree ',
#  'purpose merkle tree allow data block deliver piecemeal node download header block source small part tree relevant source still assure data correct ',
#  'reason work hash propagate upward malicious user attempt swap fake transaction bottom merkle tree change cause change node change node finally change root tree therefore hash block cause protocol register completely different block almost certainly invalid proof work ',
#  'merkle tree protocol arguably essential longterm sustainability ',
#  'full node bitcoin network store process entirety block gb disk space bitcoin network april grow gigabyte per month ',
#  'currently viable desktop computer phone later future business hobbyist able participate ',
#  'protocol simplify payment verification spv allows class node exist light node download block header verify proof work block header download branch associate transaction relevant ',
#  'allows light node determine strong guarantee security status bitcoin transaction current balance download small portion entire blockchain ',
#  'alternative blockchain application idea underlie blockchain idea apply concept also history ',
#  'nick szabo concept secure document describe new advance replicate database technology allow blockchainbased system store registry land create elaborate framework include concept homestead adverse possession georgian land tax ',
#  'however unfortunately effective replicate database system available protocol implement practice ',
#  'however bitcoins decentralize consensus developed number alternative application rapidly begin emerge ',
#  'namecoin create namecoinhttps namecoinorg best described decentralize name registration database ',
#  'decentralize protocol like tor bitcoin bitmessage need identify account people interact exist solution kind identifier available pseudorandom hash like lwwpzbqahwjltcibcrhqythaguwy ',
#  'ideally like able account name like george ',
#  'however problem person create account name george someone else use process register george impersonate ',
#  'solution firsttofile paradigm registerer succeed second fails problem perfectly suit bitcoin consensus successful implementation name registration system use idea ',
#  'color coin purpose coloredhttps docsgooglecomabuterincomdocumentd ankpcvztcmlizwdvswmqjclizrtluowuzbe edit serve protocol allow people create digital currency important trivial case currency unit digital token bitcoin blockchain ',
#  'color coin protocol issue new currency publicly assign color specific bitcoin utxo protocol recursively defines color utxo color input transaction create spent special rule apply case mixedcolor input ',
#  'allows user maintain wallet contain utxo specific color send around like regular bitcoins backtracking blockchain determine color utxo receive ',
#  'metacoins idea behind metacoin protocol life top bitcoin use bitcoin transaction store metacoin transaction different state transition function apply ',
#  'metacoin protocol prevent invalid metacoin transaction appear bitcoin blockchain rule add applystx return error protocol default applystx s provide easy mechanism create arbitrary cryptocurrency protocol potentially advanced feature implement inside bitcoin low development cost since complexity mining networking already handle bitcoin protocol ',
#  'metacoins use implement class financial contract name registration decentralize exchange ',
#  'thus general approach toward building consensus protocol building independent network building protocol top bitcoin ',
#  'former approach reasonably successful case application like namecoin difficult individual implementation need bootstrap independent blockchain building test necessary state transition networking code ',
#  'additionally predict set application decentralize consensus technology follow power law distribution vast majority application small warrant blockchain note exist large class decentralize application particularly decentralize autonomous organization need interact ',
#  'bitcoinbased approach flaw inherit simplify payment verification feature bitcoin ',
#  'spv work bitcoin use blockchain depth proxy validity point ancestor transaction far enough safe legitimately part state ',
#  'blockchainbased metaprotocols force blockchain include transaction valid within context protocol ',
#  'hence fully secure spv metaprotocol implementation need backward scan begin bitcoin blockchain determine whether certain transaction valid ',
#  'currently light implementation bitcoinbased metaprotocols rely trust server provide data arguably highly suboptimal result especially primary purpose cryptocurrency eliminate need trust ',
#  'script extension bitcoin protocol actually facilitate weak version concept smart contract ',
#  'utxo bitcoin public key also complicate script express simple stackbased program language ',
#  'paradigm transaction spending utxo provide data satisfies script ',
#  'indeed basic public key ownership mechanism implement via script script elliptic curve signature input verifies transaction address utxo return verification successful otherwise ',
#  'complicate script exist various additional use case ',
#  'example construct script require signature private key validate multisig setup useful corporate account secure saving account merchant escrow situation ',
#  'script also use pay bounty solution computational problem construct script something like bitcoin utxo provide spv proof sent dogecoin transaction denomination essentially allow decentralize crosscryptocurrency exchange ',
#  'however script language implement bitcoin several important limitation lack turingcompleteness large subset computation bitcoin script language support nearly support everything ',
#  'main category miss loop ',
#  'avoid infinite loop transaction verification theoretically surmountable obstacle script programmer since loop simulated simply repeat underlie code statement lead script spaceinefficient ',
#  'example implement alternative elliptic curve signature algorithm likely require repeat multiplication round individually include code ',
#  'valueblindness utxo script provide finegrained control amount withdrawn ',
#  'example powerful use case oracle contract hedge contract b worth btc script sends worth btc rest b require oracle determine value btc usd massive improvement term trust infrastructure requirement fully centralize solution available ',
#  'however utxo allornothing achieve inefficient hack utxo vary denomination eg ',
#  'utxo k k pick utxo send b ',
#  'lack state utxo opportunity multi stage contract script keep internal state beyond ',
#  'hard multistage option contract decentralize exchange offer twostage cryptographic commitment protocol necessary secure computational bounty ',
#  'also mean utxo use build simple oneoff contract complex stateful contract decentralize organization metaprotocols difficult implement ',
#  'binary state combine valueblindness also mean important application withdrawal limit impossible ',
#  'blockchainblindness utxo blind blockchain data nonce timestamp previous block hash ',
#  'severely limit application gamble several category deprive script language potentially valuable source randomness ',
#  'thus approach building advanced application top cryptocurrency building new blockchain use script top bitcoin building metaprotocol top bitcoin ',
#  'building new blockchain allows unlimited freedom building feature set cost development bootstrapping effort security ',
#  'use script easy implement standardize limited capability metaprotocols easy suffer fault scalability ',
#  'ethereum intend build alternative framework provide large gain ease development strong light client property allow application share economic environment blockchain security ',
#  'ethereum intent ethereum create alternative protocol building decentralize application provide different set tradeoff believe useful large class decentralize application particular emphasis situation rapid development security small rarely use application ability different application efficiently interact important ',
#  'ethereum building essentially ultimate abstract foundational layer allow anyone write smart contract decentralize application create arbitrary rule ownership transaction format state transition function ',
#  'barebones version namecoin write line code protocol like currency reputation system built twenty ',
#  'smart contract cryptographic box contain value unlock certain condition met also built top platform vastly power offer bitcoin script add power turing completeness valueawareness blockchainawareness state ',
#  'philosophy design behind ethereum intend follow follow principle ',
#  'simplicity ethereum protocol simple possible cost data storage inefficiency ',
#  'fn ',
#  'average programmer ideally able follow implement entire specificationfn ',
#  'fully realize unprecedented democratize potential cryptocurrency brings far vision ethereum protocol ',
#  'optimization add complexity include unless optimization provide substantial benefit ',
#  'universality fundamental part ethereums design philosophy ethereum featuresfn ',
#  'instead ethereum provide internal turingcomplete script language programmer use construct smart contract transaction type mathematically define ',
#  'want invent financial derivative ethereum ',
#  'want currency set ethereum contract ',
#  'want set fullscale daemon skynet need thousand interlock contract sure feed generously stop ethereum fingertip ',
#  'modularity part ethereum protocol design modular separable possible ',
#  'course development goal create program application stack continue function far modification ',
#  'innovation ethash yellowhttps ethereumgithubioyellowpaperpaperpdfappendixj wiki modify patricia tree yellow wiki rlp yphttps ethereumgithubioyellowpaperpaperpdfappendixb wiki implement separate featurecomplete library ',
#  'though use ethereum ethereum require certain feature feature still usable protocol ',
#  'ethereum development maximally benefit entire cryptocurrency ecosystem ',
#  'agility detail ethereum protocol set stone ',
#  'although extremely judicious modification highlevel construct instance sharding abstract execution data availability enshrine consensus ',
#  'computational test later development process lead u discover certain modification eg ',
#  'protocol architecture ethereum virtual machine evm substantially improve scalability security ',
#  'opportunity found exploit ',
#  'nondiscrimination noncensorship protocol attempt actively restrict prevent specific category usage ',
#  'regulatory mechanism protocol design directly regulate harm attempt oppose specific undesirable application ',
#  'programmer run infinite loop script top ethereum willing keep pay percomputationalstep transaction fee ',
#  'ethereum account ethereum state object account account byte address state transition direct transfer value information account ',
#  'ethereum account contains four field nonce counter use sure transaction process account current ether balance account contract code present account storage empty default ether main internal cryptofuel ethereum use pay transaction fee ',
#  'general type account externally account control private key contract account control contract code ',
#  'externally account code send message externally account create signing transaction contract account contract account receives message code activates allow read write internal storage send message create contract ',
#  'note contract ethereum something fulfil comply like autonomous agent live inside ethereum execution environment always execute specific piece code poked message transaction direct control ether balance keyvalue store keep track persistent variable ',
#  'message transaction term transaction use ethereum refer sign data package store message sent externally account ',
#  'transaction contain recipient message signature identify sender amount ether transfer sender recipient optional data field startgas value represent maximum number computational step transaction execution allow gasprice value represent fee sender pay per computational step standard field expect cryptocurrency ',
#  'data field function default virtual machine opcode contract use access data example use case contract function onblockchain domain registration service wish interpret data pass contain field field domain register second field ip address register ',
#  'contract read value message data appropriately storage ',
#  'startgas gasprice field crucial ethereums antidenial service model ',
#  'order prevent accidental hostile infinite loop computational wastage code transaction require set limit computational step code execution use ',
#  'fundamental unit computation gas usually computational step cost gas operation cost high amount gas computationally expensive increase amount data store part state ',
#  'also fee gas byte transaction data ',
#  'intent fee system require attacker pay proportionately resource consume include computation bandwidth storage hence transaction lead network consume amount resource gas fee roughly proportional increment ',
#  'message contract ability send message contract ',
#  'message virtual object serialize exist ethereum execution environment ',
#  'message contains sender message implicit recipient message amount ether transfer alongside message optional data field startgas value essentially message like transaction except produce contract external actor ',
#  'message produce contract currently execute code executes opcode produce executes message ',
#  'like transaction message lead recipient account run code ',
#  'thus contract relationship contract exactly external actor ',
#  'note gas allowance assign transaction contract applies total gas consume transaction sub execution ',
#  'example external actor sends transaction b gas b consumes gas send message c internal execution c consumes gas return b spend gas run gas ',
#  'ethereum state transition function ethertransitionpng ethereum state transition function applystx define follow ',
#  'check transaction wellformed ie ',
#  'number value signature valid nonce match nonce sender account ',
#  'return error ',
#  'calculate transaction fee startgas gasprice determine send address signature ',
#  'subtract fee sender account balance increment sender nonce ',
#  'enough balance spend return error ',
#  'initialize gas startgas certain quantity gas per byte pay byte transaction ',
#  'transfer transaction value sender account receive account ',
#  'receive account yet exist create ',
#  'receive account contract run contract code either completion execution run gas ',
#  'value transfer fail sender enough money code execution ran gas revert state change except payment fee add fee miner account ',
#  'otherwise refund fee remain gas sender send fee paid gas consume miner ',
#  'example suppose contract code selfstoragecalldataload selfstoragecalldataload calldataload note reality contract code write lowlevel evm code example write serpent highlevel language clarity compile evm code ',
#  'suppose contract storage start empty transaction sent ether value gas ',
#  'ether gasprice byte data byte represent number byte represent string charliefn ',
#  'process state transition function case follow ',
#  'check transaction valid form ',
#  'check transaction sender least ',
#  'ether ',
#  'subtract ether sender account ',
#  'initialize gas assume transaction byte bytefee subtract gas left ',
#  'subtract ether sender account add contract account ',
#  'run code ',
#  'case simple check contract storage index use notice set storage index value charlie ',
#  'suppose gas remain amount gas ',
#  'add ',
#  'ether sender account return result state ',
#  'contract receive end transaction total transaction fee simply equal provide gasprice multiply length transaction byte data sent alongside transaction irrelevant ',
#  'note message work equivalently transaction term reverts message execution run gas message execution execution trigger execution revert parent execution need revert ',
#  'mean safe contract contract b g gas execution guaranteed lose g gas ',
#  'finally note opcode create creates contract execution mechanic generally similar stack base bytecode language refer ethereum virtual machine code evm code ',
#  'code consists series byte byte represent operation ',
#  'general code execution infinite loop consists repeatedly carry operation current program counter begin zero incrementing program counter end code reach error stop return instruction detect ',
#  'operation access type space store data stack lastinfirstout container value push popped memory infinitely expandable byte array contract longterm storage keyvalue store ',
#  'unlike stack memory reset computation end storage persists term ',
#  'code also access value sender data incoming message block header data code also return byte array data output ',
#  'formal execution model evm code surprisingly simple ',
#  'ethereum virtual machine run full computational state define tuple blockstate transaction message code memory stack pc gas blockstate global state contain account include balance storage ',
#  'start round execution current instruction found pcth byte code pc lencode instruction definition term affect tuple ',
#  'example add pop item stack push sum reduces gas increment pc sstore pop top item stack insert second item contract storage index specify item ',
#  'although optimize ethereum virtual machine execution via justintime compilation basic implementation ethereum hundred line code ',
#  'blockchain mining applyblockdiagrampng ethereum blockchain similar bitcoin blockchain although difference ',
#  'main difference ethereum bitcoin regard blockchain architecture unlike bitcoinwhich contains copy transaction list ethereum block contain copy transaction list recent state ',
#  'aside value block number difficulty also store block ',
#  'basic block validation algorithm ethereum follow ',
#  'check previous block reference exists valid ',
#  'check timestamp block reference previous block less minute future ',
#  'check block number difficulty transaction root uncle root gas limit various lowlevel ethereumspecific concept valid ',
#  'check proof work block valid ',
#  'state end previous block ',
#  'tx block transaction list n transaction ',
#  ' n set si applysitxi ',
#  'application return error total gas consume block point exceeds gaslimit return error ',
#  'sfinal sn add block reward paid miner ',
#  'check merkle tree root state sfinal equal final state root provide block header ',
#  'block valid otherwise valid ',
#  'approach seem highly inefficient glance need store entire state block reality efficiency comparable bitcoin ',
#  'reason state store tree structure block small part tree need change ',
#  'thus general therefore data store reference twice use pointer ie ',
#  'hash subtrees ',
#  'special kind tree patricia tree use accomplish include modification merkle tree concept allows node insert delete change efficiently ',
#  'additionally state information part block need store entire blockchain history strategy apply bitcoin calculate provide x saving space ',
#  'commonly ask question contract code execute term physical hardware ',
#  'simple answer process execute contract code part definition state transition function part block validation algorithm transaction add block b code execution spawn transaction execute node future download validate block b ',
#  'application general type application top ethereum ',
#  'category financial application provide user powerful manage enter contract use money ',
#  'include subcurrencies financial derivative hedge contract saving wallet ultimately class fullscale employment contract ',
#  'second category semifinancial application money involve also heavy nonmonetary side perfect example selfenforcing bounty solution computational problem ',
#  'finally application online voting decentralize governance financial ',
#  'token system onblockchain token system application range subcurrencies represent asset usd gold company stock individual token represent smart property secure unforgeable coupon token system tie conventional value use point system incentivization ',
#  'token system surprisingly easy implement ethereum ',
#  'key point understand currency token system fundamentally database operation subtract x unit x unit b provision least x unit transaction transaction approve a implement token system implement logic contract ',
#  'basic code implement token system serpent follow def sendto value selfstoragemsgsender value selfstoragemsgsender selfstoragemsgsender value selfstorageto selfstorageto value essentially literal implementation banking system state transition function described far document ',
#  'extra line code need add provide initial step distribute currency unit edge case ideally function add contract query balance address ',
#  'theoretically ethereumbased token system act sub currency potentially include important feature chain bitcoinbased metacurrencies lack ability pay transaction fee directly currency ',
#  'implement contract maintain ether balance refund ether use pay fee sender refill balance collect internal currency unit fee resell constant run auction ',
#  'user thus need activate account ether ether reusable contract refund ',
#  'financial derivative stablevalue currency financial derivative common application smart contract simplest implement code ',
#  'main challenge implement financial contract majority require reference external price ticker example desirable application smart contract hedge volatility ether cryptocurrency respect u dollar require contract value ethusd ',
#  'simplest data feed contract maintain specific party eg ',
#  'nasdaq design party ability update contract need provide interface allows contract send message contract response provide price ',
#  'critical ingredient hedge contract follow ',
#  'wait party input ether ',
#  'wait party b input ether ',
#  'record usd value ether calculate query data feed contract storage x ',
#  'allow b reactivate contract order send x worth ether calculate query data feed contract new price rest b contract significant potential crypto commerce ',
#  'main problem cite cryptocurrency fact volatile although user merchant want security convenience deal cryptographic asset wish prospect lose value fund single ',
#  'commonly propose solution issuerbacked asset idea issuer creates subcurrency issue revoke unit provide unit currency anyone provide offline unit specify underlie asset eg ',
#  'gold usd ',
#  'issuer promise provide unit underlie asset anyone sends unit cryptoasset ',
#  'mechanism allows non cryptographic asset uplifted cryptographic asset provide issuer trust ',
#  'practice however issuer always trustworthy case banking infrastructure weak hostile service exist ',
#  'financial derivative provide alternative ',
#  'instead single issuer provide fund asset decentralize market speculator bet price cryptographic reference asset eg ',
#  'eth play role ',
#  'unlike issuer speculator option default side bargain hedge contract hold fund escrow ',
#  'note approach fully decentralize trust source still need provide price ticker although arguably still massive improvement term reduce infrastructure requirement unlike issuer issue price feed require license likely categorize free speech reduce potential fraud ',
#  'identity reputation system early alternative cryptocurrency namecoinhttp namecoinorg attempt use bitcoinlike blockchain provide name registration system user register name public database alongside data ',
#  'major cite use case dns system mapping domain name like bitcoinorg namecoins case bitcoinbit ip address ',
#  'use case include email authentication potentially advanced reputation system ',
#  'basic contract provide namecoinlike name registration system ethereum def registername value selfstoragename selfstoragename value contract simple database inside ethereum network add modify remove ',
#  'anyone register name value registration stick forever ',
#  'sophisticated name registration contract also function clause allow contract query mechanism owner ie ',
#  'registerer name change data transfer ownership ',
#  'add reputation weboftrust functionality top ',
#  'decentralize file storage past year emerge number popular online file storage startup prominent dropbox point file storage market relatively inefficient cursory various exist show particularly uncanny valley gb level neither free quota enterpriselevel discount kick monthly price mainstream file storage cost pay cost entire hard drive single month ',
#  'ethereum contract allow development decentralize file storage ecosystem individual user earn small quantity money rent hard drive unused space use far drive cost file storage ',
#  'key underpin piece device term decentralize dropbox contract ',
#  'contract work follow ',
#  'split desire data block encrypt block privacy build merkle tree ',
#  'contract rule n block contract pick random index merkle tree use previous block hash accessible contract code source randomness x ether entity supply transaction simplify payment verificationlike proof ownership block particular index tree ',
#  'user want redownload file use micropayment channel protocol eg ',
#  'pay szabo per kilobyte recover file feeefficient approach payer publish transaction end instead replace transaction slightly lucrative nonce kilobyte ',
#  'important feature protocol although seem like trust random node decide forget file reduce risk nearzero splitting file piece via secret share watch contract piece still node possession ',
#  'contract still pay money provide cryptographic proof someone still store file ',
#  'decentralize autonomous organization virtual entity certain set member shareholder perhaps majority spend entity fund modify code ',
#  'member collectively decide organization allocate fund ',
#  'method allocate daos fund range bounty salary exotic mechanism internal currency reward work ',
#  'essentially replicates legal trapping traditional company nonprofit use cryptographic blockchain technology enforcement ',
#  'far talk around daos around capitalist model decentralize autonomous corporation dac dividend receive shareholder tradable share alternative perhaps described decentralize autonomous community member equal share decision require exist member agree add remove member ',
#  'requirement person membership need enforce collectively group ',
#  'general outline code dao follow ',
#  'simplest design simply piece selfmodifying code change third member agree change ',
#  'although code theoretically immutable easily around defacto mutability chunk code separate contract address contract store modifiable storage ',
#  'simple implementation dao contract transaction type distinguish data provide transaction ikv register proposal index change address storage index k value v register vote favor proposal finalize proposal enough vote contract clause ',
#  'maintain record storage change along list vote ',
#  'also list member ',
#  'storage change third member voting finalize transaction execute change ',
#  'sophisticated skeleton also builtin voting ability feature like send transaction add member remove member provide liquidstyle vote delegation ie ',
#  'anyone assign someone vote assignment transitive assigns b b assigns c c determines vote ',
#  'design allow dao grow organically decentralize community allow people eventually delegate task filter member specialist although unlike current system specialist easily pop existence individual community member change alignment ',
#  'alternative model decentralize corporation account zero share third share require decision ',
#  'complete skeleton involve asset management functionality ability offer buy sell share ability accept offer preferably ordermatching mechanism inside contract ',
#  'delegation also exist liquid democracystyle generalize concept board director ',
#  'far application ',
#  'saving wallet ',
#  'suppose alice want keep fund safe worried lose someone hack private key ',
#  'ether contract bob bank follow alice alone withdraw maximum fund per ',
#  'bob alone withdraw maximum fund per alice ability transaction key shut ability ',
#  'alice bob together withdraw anything ',
#  'normally per enough alice alice want withdraw contact bob help ',
#  'alices key hack run bob move fund new contract ',
#  'loses key bob fund eventually ',
#  'bob malicious ability withdraw ',
#  'style style ',
#  'crop insurance ',
#  'easily financial derivative contract use data feed weather instead price index ',
#  'farmer iowa purchase derivative pay inversely base precipitation iowa drought farmer automatically receive money enough rain farmer happy crop ',
#  'expand natural disaster insurance generally ',
#  'decentralize data feed ',
#  'financial contract difference actually possible decentralize data feed via protocol schellingcoinhttp blogethereumorgschellingcoinaminimal trustuniversaldatafeed ',
#  'schellingcoin basically work follow n party system value datum eg ',
#  'ethusd price value sort everyone th th percentile token reward ',
#  'everyone incentive provide answer everyone else provide value large number player realistically agree obvious default truth ',
#  'creates decentralize protocol theoretically provide number value include ethusd price temperature berlin result particular hard computation ',
#  'smart multisignature escrow ',
#  'bitcoin allows multisignature transaction contract example five key spend fund ',
#  'ethereum allows granularity example four five spend everything five spend per five spend ',
#  'per ',
#  'additionally ethereum multisig asynchronous party register signature blockchain different signature automatically send transaction ',
#  'cloud compute ',
#  'evm technology also use create verifiable compute environment allow user ask others carry computation laptop specialized server spot check together security deposit use ensure system trustworthy ie ',
#  'node profitably cheat ',
#  'although system suitable task task require high level interprocess communication example easily large cloud node ',
#  'task however easy parallelize project like setihome foldinghome genetic algorithm easily implement top platform ',
#  'peertopeer gamble ',
#  'number peertopeer gamble protocol frank stajano richard claytons cyberdice implement ethereum blockchain ',
#  'simplest gamble protocol actually simply contract difference next block hash advanced protocol built create gamble service nearzero fee ability cheat ',
#  'prediction market ',
#  'provide oracle schellingcoin prediction market also easy implement prediction market together schellingcoin prove mainstream application futarchy governance protocol decentralize organization ',
#  'onchain decentralize marketplace use identity reputation system base ',
#  'miscellanea concern modify ghost implementation greedy heaviest observe subtree ghost protocol innovation introduce yonatan sompolinsky aviv zohar december ',
#  'motivation behind ghost blockchains fast confirmation miner mine block miner b happens mine block miner block propagates b miner b block end waste contribute network security ',
#  'furthermore centralization issue miner mining pool hashpower b hashpower risk produce stale block since produce block mining data immediately whereas b risk produce stale block ',
#  'thus block interval short enough stale rate high substantially efficient simply virtue size ',
#  'effect combine blockchains produce block quickly likely lead mining pool large enough percentage network hashpower de facto control mining process ',
#  'described sompolinsky zohar ghost solves issue network security loss include stale block calculation chain parent far ancestor block also stale descendant block ancestor ethereum jargon uncle add calculation block large total proof work backing ',
#  'solve second issue centralization bias beyond protocol described sompolinsky zohar also provide block reward stales stale block receives ',
#  'base reward nephew include stale block receives remain  transaction fee however award uncle ',
#  'ethereum implement simplify version ghost seven level ',
#  'specifically define follow block specify parent specify uncle uncle include block b follow property direct child kth generation ancestor b k ',
#  'ancestor b uncle valid block header need previously verify valid block uncle different uncle include previous block uncle include block nondoubleinclusion uncle u block b miner b additional ',
#  'add coinbase reward miner u ',
#  'standard coinbase reward ',
#  'limited version ghost uncle includable generation use reason ',
#  'unlimited ghost include complication calculation uncle block valid ',
#  'second unlimited ghost compensation use ethereum remove incentive miner mine main chain chain public attacker ',
#  'fee transaction publish blockchain imposes network cost need download verify need regulatory mechanism typically involve transaction fee prevent abuse ',
#  'default approach use bitcoin purely voluntary fee rely miner act gatekeeper set dynamic minimum ',
#  'approach receive favorably bitcoin community particularly marketbased allow supply demand miner transaction sender determine price ',
#  'problem line reason however transaction processing market although intuitively attractive construe transaction processing service miner offering sender reality transaction miner include need process node network vast majority cost transaction processing borne third party miner decision whether include ',
#  'hence tragedyofthecommons problem likely occur ',
#  'however flaw marketbased mechanism particular inaccurate simplify assumption magically cancel ',
#  'argument follow ',
#  'suppose ',
#  'transaction lead k operation offering reward kr miner include r set sender k r roughly visible miner beforehand ',
#  'operation processing cost c node ie ',
#  'node equal efficiency ',
#  'n mining node exactly equal processing power ie ',
#  'n total ',
#  'nonmining full node exist ',
#  'miner willing process transaction expect reward cost ',
#  'thus expect reward krn since miner n chance processing next block processing cost miner simply kc ',
#  'hence miner include transaction krn kc r nc ',
#  'note r peroperation fee provide sender thus low bound benefit sender derives transaction nc cost entire network together processing operation ',
#  'hence miner incentive include transaction total utilitarian benefit exceeds cost ',
#  'however several important deviation assumption reality ',
#  'miner pay high cost process transaction verify node since extra verification delay block propagation thus increase chance block become stale ',
#  'exist nonmining full node ',
#  'mining power distribution end radically inegalitarian practice ',
#  'speculator political enemy crazy whose utility function include cause harm network exist cleverly set contract cost low cost paid verify node ',
#  'provide tendency miner include transaction increase nc hence effect least partially cancel outhow major issue solve simply institute float cap block operation blklimitfactor longterm exponential move average ',
#  'specifically blkoplimit floorblkparentoplimit emafactor floorparentopcount blklimitfactor emafactor blklimitfactor emafactor constant set ',
#  'likely change far analysis ',
#  'factor disincentivizing large block size bitcoin block large longer propagate thus high probability become stales ',
#  'ethereum highly gas consume block also longer propagate physically large longer process transaction state transition validate ',
#  'delay disincentive significant consideration bitcoin less ethereum ghost protocol hence rely regulate block limit provide stable baseline ',
#  'computation turingcompleteness important note ethereum virtual machine turing complete mean evm code encode computation conceivably carry include infinite loop ',
#  'evm code allows loop ',
#  'jump instruction allows program jump previous spot code jumpi instruction conditional jumping allow statement like x x x ',
#  'second contract contract potentially allow loop recursion ',
#  'naturally lead problem malicious user essentially shut miner full node force enter infinite loop issue arises problem computer science halt problem tell general case whether program halt ',
#  'described state transition section solution work require transaction set maximum number computational execution longer computation revert fee still paid ',
#  'message work ',
#  'show motivation behind solution consider follow example attacker creates contract run infinite loop sends transaction activate loop miner ',
#  'miner process transaction run infinite loop wait run gas ',
#  'though execution run gas stop halfway transaction still valid miner still claim fee attacker computational step ',
#  'attacker creates infinite loop intent force miner keep compute computation finish block possible miner include transaction claim fee ',
#  'however attacker require submit value startgas limit number computational step execution miner ahead computation excessively large number step ',
#  'attacker contract code form like sendacontractstoragea contractstoragea sends transaction enough gas run step second ie ',
#  'withdrawal balance ',
#  'contract author need worry protect attack execution stop halfway change revert ',
#  'financial contract work median nine proprietary data feed order minimize risk ',
#  'attacker data feed design modifiable via variableaddresscall mechanism described section daos convert run infinite loop thereby attempt force attempt claim fund financial contract run gas ',
#  'however financial contract set gas limit message prevent problem ',
#  'alternative turingcompleteness turingincompleteness jump jumpi exist copy contract allow exist stack ',
#  'system fee system described uncertainty around effectiveness solution necessary cost execute contract bound size ',
#  'additionally turingincompleteness big limitation contract example conceive internally far require loop loop remove repetition oneline piece code ',
#  'serious implication turingcompleteness limited benefit simply turingincomplete language reality however turingincompleteness far neat solution problem ',
#  'consider follow contract c callc callc c callc callc c callc callc  c callc callc c run step program record change storage send transaction a thus transaction contract computational step ',
#  'miner try detect logic bomb ahead maintain value alongside contract specify maximum number computational step calculate contract contract recursively require miner forbid contract create contract since creation execution contract easily roll single contract ',
#  'problematic point address field message variable general possible tell contract contract ahead ',
#  'hence surprising conclusion turingcompleteness surprisingly easy manage lack turingcompleteness equally surprisingly difficult manage unless exact control case protocol turingcomplete currency issuance ethereum network include builtin currency ether serf dual purpose provide primary liquidity layer allow efficient exchange various type digital asset importantly provide mechanism pay transaction fee ',
#  'convenience avoid future argument current mbtcubtcsatoshi debate bitcoin denomination prelabelled wei szabo finney ether expand version concept dollar cent btc satoshi ',
#  'near future expect ether use ordinary transaction finney microtransactions szabo wei technical discussion around fee protocol implementation remain denomination become useful later include client point ',
#  'issuance model follow ether release currency sale price ether per btc mechanism intend fund ethereum organization pay development use success platform mastercoin nxt ',
#  'earlier buyer benefit large discount ',
#  'btc receive sale use entirely pay salary bounty developer invest various forprofit nonprofit project ethereum cryptocurrency ecosystem ',
#  'x total amount sell eth allocate organization compensate early contributor pay ethdenominated expense genesis block ',
#  'x total amount sell maintain longterm reserve ',
#  'x total amount sell allocate miner per year forever point ',
#  'group launch year year currency unit x x x purchaser ',
#  'reserve spent presale ',
#  'reserve use postsale ',
#  'miner ',
#  'longterm supply growth rate percent spv despite linear currency issuance like bitcoin supply growth rate nevertheless tends zero main choice model existence size endowment pool existence permanently grow linear supply oppose capped supply bitcoin ',
#  'justification endowment pool follow ',
#  'endowment pool exist linear issuance reduce x provide inflation rate total quantity ether ',
#  'less unit ',
#  'valuable ',
#  'hence equilibrium ',
#  'ether purchase sale unit exactly valuable ',
#  'organization also x btc consider split slice original btc additional x ',
#  'hence situation exactly equivalent endowment important difference organization hold purely btc incentivized support value ether unit ',
#  'permanent linear supply growth model reduces risk excessive wealth concentration bitcoin individual living present future era fair chance acquire currency unit retain strong incentive obtain hold ether supply growth rate percentage still tends zero ',
#  'also theorize coin always lose due carelessness death etc coin loss model percentage total supply per year total currency supply circulation fact eventually stabilize value equal annual issuance divide loss rate eg ',
#  'loss rate supply create equilibrium ',
#  'note future likely ethereum switch proofofstake model security reduce issuance requirement somewhere zero x per year ',
#  'event ethereum organization loses funding reason disappears leave social contract anyone create future candidate version ethereum condition quantity ether equal ',
#  'n n number year genesis block ',
#  'creator free crowdsell otherwise assign difference posdriven supply expansion maximum allowable supply expansion pay development ',
#  'candidate upgrade comply social contract justifiably fork compliant version ',
#  'mining centralization bitcoin mining algorithm work miner compute sha slightly modify version block header million eventually node version whose hash less target currently around ',
#  'however mining algorithm vulnerable form centralization ',
#  'mining ecosystem dominate asics applicationspecific integrate circuit computer chip design therefore thousand efficient specific task bitcoin mining ',
#  'mean bitcoin mining longer highly decentralize egalitarian pursuit require million dollar capital effectively participate ',
#  'second bitcoin miner actually perform block validation locally instead rely centralize mining pool provide block header ',
#  'problem arguably bad write top mining pool indirectly control roughly processing power bitcoin network although mitigate fact miner switch mining pool pool coalition attempt attack ',
#  'current intent ethereum use mining algorithm miner require fetch random data state compute randomly select transaction n block blockchain return hash result ',
#  'important benefit ',
#  'ethereum contract include kind computation ethereum asic essentially asic general computation ie ',
#  'cpu ',
#  'second mining require access entire blockchain force miner store entire blockchain least capable verify transaction ',
#  'remove need centralize mining pool although mining pool still serve legitimate role randomness reward distribution function serve equally peertopeer pool central control ',
#  'model untested difficulty along avoid certain clever optimization use contract execution mining algorithm ',
#  'however notably interest feature algorithm allows anyone poison introduce large number contract blockchain specifically design stymie certain asics ',
#  'economic incentive exist asic manufacturer use trick attack ',
#  'thus solution develop ultimately adaptive economic human solution purely technical ',
#  'scalability common concern ethereum issue scalability ',
#  'like bitcoin ethereum suffers flaw transaction need process node network ',
#  'bitcoin size current blockchain rest gb grow mb per hour ',
#  'bitcoin network process visa transaction per second grow mb per second gb per hour tb per year ',
#  'ethereum likely suffer similar growth pattern worsen fact application top ethereum blockchain instead currency case bitcoin ameliorate fact ethereum full node need store state instead entire blockchain history ',
#  'problem large blockchain size centralization risk ',
#  'blockchain size increase tb likely scenario small number large business run full node regular user use light spv node ',
#  'situation arises potential concern full node band together agree cheat profitable fashion eg ',
#  'change block reward btc ',
#  'light node detect immediately ',
#  'course least honest full node likely exist hour information fraud trickle channel like reddit point late ordinary user organize effort blacklist block massive likely infeasible coordination problem similar scale pull successful attack ',
#  'case bitcoin currently problem exists blockchain modification suggest alleviate issue ',
#  'near term ethereum use additional strategy cope problem ',
#  'blockchainbased mining algorithm least miner force full node create low bound number full node ',
#  'second importantly however include intermediate state tree root blockchain processing transaction ',
#  'block validation centralize honest verify node exists centralization problem circumvent via verification protocol ',
#  'miner publishes invalid block block either badly format state sn incorrect ',
#  'since correct state si incorrect si correct ',
#  'verify node provide index along proof invalidity consist subset patricia tree node need process applysitxi si ',
#  'node able use patricia node run part computation si generate match si provide ',
#  'sophisticated attack involve malicious miner publishing incomplete block full information challenge form target transaction index receive node light node treat block untrusted node whether miner verifier provide subset patricia node proof validity ',
#  'conclusion ethereum protocol originally conceive upgraded version cryptocurrency provide advanced feature onblockchain escrow withdrawal limit financial contract gamble market like via highly generalize program language ',
#  'ethereum protocol support application directly existence turing complete program language mean arbitrary contract theoretically create transaction type application ',
#  'interest ethereum however ethereum protocol move far beyond currency ',
#  'protocol around decentralize file storage decentralize computation decentralize prediction market among dozen concept potential substantially increase efficiency computational industry provide massive boost peertopeer protocol add economic layer ',
#  'finally also substantial array application money ',
#  'concept arbitrary state transition function implement ethereum protocol provide platform unique potential closedended singlepurpose protocol intend specific array application data storage gamble finance ethereum openended design believe extremely wellsuited serve foundational layer large number financial nonfinancial protocol year ',
#  'note far reading note ',
#  'sophisticated reader notice fact bitcoin address hash elliptic curve public key public key ',
#  'however fact perfectly legitimate cryptographic terminology refer pubkey hash public key ',
#  'bitcoins cryptography consider custom digital signature algorithm public key consists hash ecc pubkey signature consists ecc pubkey concatenate ecc signature verification algorithm involves check ecc pubkey signature ecc pubkey hash provide public key verify ecc signature ecc pubkey ',
#  'technically median previous block ',
#  'ethereum protocol simple practical necessary high level complexity instance scale internalize cost storage bandwidth io security privacy transparency etc ',
#  'complexity necessary documentation clear concise uptodate possible someone completely unschooled ethereum learn become expert ',
#  'yellow ethereum virtual machine useful specification reference building ethereum client scratch also topic ethereumhttps githubcomethereumwikiwiki sharding developmment core development dapp development research casper rd networking protocol ',
#  'research possible future implementation ethresearch ',
#  'express abstraction ',
#  'latesthttps ethresearchtshardingphasespec planning abstract execution allow execution engine necessarily follow canonical specification instance tailor specific application shard ',
#  'heterogeneity execution engine explicitly state roadmap ',
#  'also heterogeneous sharding vlad zamfir conceptualize ',
#  'internally charlie number latter bigendian base representation ',
#  'number least ',
#  'far reading ',
#  'intrinsic value triangle http enwikipediaorgwikizookostriangle ',
#  'color coin whitepaper bitcoin magazine jeff garzik http garzikrantsblogspotcastorjandbitcoinautonomous agentshtml ',
#  'mike hearn smart property turing festival striangle striangle']

# %%
tokenizer = nltk.tokenize.RegexpTokenizer('\s+', gaps=True)
tokens = [tokenizer.tokenize(s) for s in corpora["Ethereum"]] # It takes some time; inbuilt tokenizer cannot detect shortform like don't, I've etc
print('We have', np.reshape(np.concatenate(tokens), -1).shape[0], 'words in total. \n') # DON'T do len(sum(tokens,[])) because of speed

# Lower 
tokens = [[t.lower().replace('.','') for t in s] for s in tokens]

print(tokens[5])
# Out:
# We have 7315 words in total.
#
# ['ethereum', 'intends', 'provide', 'blockchain', 'builtin', 'fully', 'fledged', 'turingcomplete', 'programming', 'language', 'used', 'create', 'contracts', 'used', 'encode', 'arbitrary', 'state', 'transition', 'functions', 'allowing', 'users', 'create', 'systems', 'described', 'others', 'yet', 'imagined', 'simply', 'writing', 'logic', 'lines', 'code']

# %%
from nltk.probability import FreqDist

# Turn corpus into np before unnest the list
tokens = np.array([np.array(s) for s in tokens]) # numpy can handle text as well

fdist = FreqDist(np.concatenate(tokens))

fdist.most_common(5)

import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
from nltk import bigrams, ngrams
bigrams_tokens = bigrams(np.concatenate(tokens))
fdist_bigrams = FreqDist(list(bigrams_tokens))
fdist_bigrams.plot(30,cumulative=False)
plt.show()
